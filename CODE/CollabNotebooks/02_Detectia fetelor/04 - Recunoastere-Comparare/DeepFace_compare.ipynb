# %%
# !pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 12.4 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=6ac235feeb8061df13d97a94c5aab2650d07a0564e85f542f7703f0684436805
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# ...

# %%
from deepface import DeepFace
import cv2
from google.colab import files
from IPython.display import display
from google.colab.patches import cv2_imshow
# Out:
# 25-05-11 10:38:31 - Directory /root/.deepface has been created
# 25-05-11 10:38:31 - Directory /root/.deepface/weights has been created

# %%
print("Incarcati prima imagine de test")
uploaded_test_image_1 = files.upload()  # Allows user to upload a file
# Get the first uploaded file
uploaded_test_image_1_path = list(uploaded_test_image_1.keys())[0]
# Out:
# Incarcati prima imagine de test
#      <input type="file" id="files-39f2b35c-99dd-4172-8b79-31e50a625cc4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-39f2b35c-99dd-4172-8b79-31e50a625cc4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
print("Incarcati a doua imagine de test")
uploaded_test_image_2 = files.upload()  # Allows user to upload a file
# Get the first uploaded file
uploaded_test_image_2_path = list(uploaded_test_image_2.keys())[0]
# Out:
# Incarcati a doua imagine de test
#      <input type="file" id="files-cd533051-f5a8-4354-a1d7-4477d97556eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd533051-f5a8-4354-a1d7-4477d97556eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
img1 = cv2.imread(uploaded_test_image_1_path)
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=600x900>

# %%
img2 = cv2.imread(uploaded_test_image_2_path)
cv2_imshow(img2)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
obj = DeepFace.verify(uploaded_test_image_1_path, uploaded_test_image_2_path, model_name = 'ArcFace', detector_backend = 'retinaface')

# %%
print(obj)
# Out:
# {'verified': True, 'distance': 0.6549723215043424, 'threshold': 0.68, 'model': 'ArcFace', 'detector_backend': 'retinaface', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 126, 'y': 150, 'w': 328, 'h': 468, 'left_eye': (385, 341), 'right_eye': (234, 330)}, 'img2': {'x': 676, 'y': 288, 'w': 549, 'h': 741, 'left_eye': (1076, 568), 'right_eye': (812, 592)}}, 'time': 20.43}
